# %% [markdown]
# **Requirements**
# * According to this [paper](https://arxiv.org/pdf/1904.01561.pdf), features are computed with [descriptastorus](https://github.com/bp-kelley/descriptastorus) package
# * Install via: `pip install git+https://github.com/bp-kelley/descriptastorus`

# %% [markdown]
# ## General imports

# %%
import sys 
sys.path.insert(0, "/")  # this depends on the notebook depth and must be adapted per notebook
# from compert.paths import DATA_DIR, EMBEDDING_DIR
sys.path.append("/root/project/src/project_src/state_transition_model/benchmark/chemCPA/chemCPA-main/chemCPA")
from paths import DATA_DIR, EMBEDDING_DIR

# %%
import numpy as np
from joblib import Parallel, delayed
from tqdm.notebook import tqdm

# %% [markdown]
# ## Load Smiles list

# %%
import pandas as pd 
import scanpy as sc
adata = sc.read("/root/project/data/preprocessed_data/state_transition_model_benchmark/chemCPA/lincs_preprocess_2.h5ad", backed=True)
unique_smiles = np.unique(adata.obs["canonical_smiles"])

# %%
smiles_df = pd.DataFrame(unique_smiles)
smiles_df.columns = ["smiles"]

# %%
smiles_list = smiles_df['smiles'].values

# %%
print(f'Number of smiles strings: {len(smiles_list)}')
# Out:
# Number of smiles strings: 7963

# %%
from descriptastorus.descriptors.DescriptorGenerator import MakeGenerator
generator = MakeGenerator(("RDKit2D",))
for name, numpy_type in generator.GetColumns():
    print(f"{name}({numpy_type.__name__})")
# Out:
# RDKit2D_calculated(bool)
# BalabanJ(float64)
# BertzCT(float64)
# Chi0(float64)
# Chi0n(float64)
# Chi0v(float64)
# Chi1(float64)
# Chi1n(float64)
# Chi1v(float64)
# Chi2n(float64)
# Chi2v(float64)
# Chi3n(float64)
# Chi3v(float64)
# Chi4n(float64)
# Chi4v(float64)
# EState_VSA1(float64)
# EState_VSA10(float64)
# EState_VSA11(float64)
# EState_VSA2(float64)
# EState_VSA3(float64)
# EState_VSA4(float64)
# EState_VSA5(float64)
# EState_VSA6(float64)
# EState_VSA7(float64)
# EState_VSA8(float64)
# EState_VSA9(float64)
# ExactMolWt(float64)
# FpDensityMorgan1(float64)
# FpDensityMorgan2(float64)
# FpDensityMorgan3(float64)
# FractionCSP3(float64)
# HallKierAlpha(float64)
# HeavyAtomCount(float64)
# HeavyAtomMolWt(float64)
# Ipc(float64)
# Kappa1(float64)
# Kappa2(float64)
# Kappa3(float64)
# LabuteASA(float64)
# MaxAbsEStateIndex(float64)
# MaxAbsPartialCharge(float64)
# MaxEStateIndex(float64)
# MaxPartialCharge(float64)
# MinAbsEStateIndex(float64)
# MinAbsPartialCharge(float64)
# MinEStateIndex(float64)
# MinPartialCharge(float64)
# MolLogP(float64)
# MolMR(float64)
# MolWt(float64)
# NHOHCount(float64)
# NOCount(float64)
# NumAliphaticCarbocycles(float64)
# NumAliphaticHeterocycles(float64)
# NumAliphaticRings(float64)
# NumAromaticCarbocycles(float64)
# NumAromaticHeterocycles(float64)
# NumAromaticRings(float64)
# NumHAcceptors(float64)
# NumHDonors(float64)
# NumHeteroatoms(float64)
# NumRadicalElectrons(float64)
# NumRotatableBonds(float64)
# NumSaturatedCarbocycles(float64)
# NumSaturatedHeterocycles(float64)
# NumSaturatedRings(float64)
# NumValenceElectrons(float64)
# PEOE_VSA1(float64)
# PEOE_VSA10(float64)
# PEOE_VSA11(float64)
# PEOE_VSA12(float64)
# PEOE_VSA13(float64)
# PEOE_VSA14(float64)
# PEOE_VSA2(float64)
# PEOE_VSA3(float64)
# PEOE_VSA4(float64)
# PEOE_VSA5(float64)
# PEOE_VSA6(float64)
# PEOE_VSA7(float64)
# PEOE_VSA8(float64)
# PEOE_VSA9(float64)
# RingCount(float64)
# SMR_VSA1(float64)
# SMR_VSA10(float64)
# SMR_VSA2(float64)
# SMR_VSA3(float64)
# SMR_VSA4(float64)
# SMR_VSA5(float64)
# SMR_VSA6(float64)
# SMR_VSA7(float64)
# SMR_VSA8(float64)
# SMR_VSA9(float64)
# SlogP_VSA1(float64)
# SlogP_VSA10(float64)
# SlogP_VSA11(float64)
# SlogP_VSA12(float64)
# SlogP_VSA2(float64)
# SlogP_VSA3(float64)
# SlogP_VSA4(float64)
# SlogP_VSA5(float64)
# SlogP_VSA6(float64)
# SlogP_VSA7(float64)
# SlogP_VSA8(float64)
# SlogP_VSA9(float64)
# TPSA(float64)
# VSA_EState1(float64)
# VSA_EState10(float64)
# VSA_EState2(float64)
# VSA_EState3(float64)
# VSA_EState4(float64)
# VSA_EState5(float64)
# VSA_EState6(float64)
# VSA_EState7(float64)
# VSA_EState8(float64)
# VSA_EState9(float64)
# fr_Al_COO(float64)
# fr_Al_OH(float64)
# fr_Al_OH_noTert(float64)
# fr_ArN(float64)
# fr_Ar_COO(float64)
# fr_Ar_N(float64)
# fr_Ar_NH(float64)
# fr_Ar_OH(float64)
# fr_COO(float64)
# fr_COO2(float64)
# fr_C_O(float64)
# fr_C_O_noCOO(float64)
# fr_C_S(float64)
# fr_HOCCN(float64)
# fr_Imine(float64)
# fr_NH0(float64)
# fr_NH1(float64)
# fr_NH2(float64)
# fr_N_O(float64)
# fr_Ndealkylation1(float64)
# fr_Ndealkylation2(float64)
# fr_Nhpyrrole(float64)
# fr_SH(float64)
# fr_aldehyde(float64)
# fr_alkyl_carbamate(float64)
# fr_alkyl_halide(float64)
# fr_allylic_oxid(float64)
# fr_amide(float64)
# fr_amidine(float64)
# fr_aniline(float64)
# fr_aryl_methyl(float64)
# fr_azide(float64)
# fr_azo(float64)
# fr_barbitur(float64)
# fr_benzene(float64)
# fr_benzodiazepine(float64)
# fr_bicyclic(float64)
# fr_diazo(float64)
# fr_dihydropyridine(float64)
# fr_epoxide(float64)
# fr_ester(float64)
# fr_ether(float64)
# fr_furan(float64)
# fr_guanido(float64)
# fr_halogen(float64)
# fr_hdrzine(float64)
# fr_hdrzone(float64)
# fr_imidazole(float64)
# fr_imide(float64)
# fr_isocyan(float64)
# fr_isothiocyan(float64)
# fr_ketone(float64)
# fr_ketone_Topliss(float64)
# fr_lactam(float64)
# fr_lactone(float64)
# fr_methoxy(float64)
# fr_morpholine(float64)
# fr_nitrile(float64)
# fr_nitro(float64)
# fr_nitro_arom(float64)
# fr_nitro_arom_nonortho(float64)
# fr_nitroso(float64)
# fr_oxazole(float64)
# fr_oxime(float64)
# fr_para_hydroxylation(float64)
# fr_phenol(float64)
# fr_phenol_noOrthoHbond(float64)
# fr_phos_acid(float64)
# fr_phos_ester(float64)
# fr_piperdine(float64)
# fr_piperzine(float64)
# fr_priamide(float64)
# fr_prisulfonamd(float64)
# fr_pyridine(float64)
# fr_quatN(float64)
# fr_sulfide(float64)
# fr_sulfonamd(float64)
# fr_sulfone(float64)
# fr_term_acetylene(float64)
# fr_tetrazole(float64)
# fr_thiazole(float64)
# fr_thiocyan(float64)
# fr_thiophene(float64)
# fr_unbrch_alkane(float64)
# fr_urea(float64)
# qed(float64)

# %%
n_jobs = 1
data = Parallel(n_jobs=n_jobs)(delayed(generator.process)(smiles) for smiles in tqdm(smiles_list, position=0, leave=True) )
# Out:
#   0%|          | 0/7963 [00:00<?, ?it/s]

# %%
embedding = np.array(data)
embedding.shape
# Out:
# (7963, 201)

# %% [markdown]
# ## Check `nans` and `infs`

# %% [markdown]
# Check for `nans`

# %%
drug_idx, feature_idx = np.where(np.isnan(embedding))
print(f'drug_idx:\n {drug_idx}')
print(f'feature_idx:\n {feature_idx}')
# Out:
# drug_idx:
#  [1372 1372 1372 1372 1862 1862 1862 1862 1919 1919 1919 1919 3911 3911
#  3911 3911 5927 5927 5927 5927 5928 5928 5928 5928 5929 5929 5929 5929
#  6300 6300 6300 6300 7442 7442 7442 7442 7557 7557 7557 7557 7612 7612
#  7612 7612]
# feature_idx:
#  [40 42 44 46 40 42 44 46 40 42 44 46 40 42 44 46 40 42 44 46 40 42 44 46
#  40 42 44 46 40 42 44 46 40 42 44 46 40 42 44 46 40 42 44 46]

# %% [markdown]
# Check for `infs` and add to idx lists

# %%
drug_idx_infs, feature_idx_infs = np.where(np.isinf(embedding))

drug_idx = np.concatenate((drug_idx, drug_idx_infs))
feature_idx = np.concatenate((feature_idx, feature_idx_infs))

# %% [markdown]
# Features that have these invalid values:

# %%
np.array(generator.GetColumns())[np.unique(feature_idx)]
# Out:
# array([['MaxAbsPartialCharge', <class 'numpy.float64'>],
#        ['MaxPartialCharge', <class 'numpy.float64'>],
#        ['MinAbsPartialCharge', <class 'numpy.float64'>],
#        ['MinPartialCharge', <class 'numpy.float64'>]], dtype=object)

# %% [markdown]
# Set values to `0`

# %%
embedding[drug_idx, feature_idx]
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, inf, inf, inf, inf, inf, inf])

# %%
embedding[drug_idx, feature_idx] = 0

# %% [markdown]
# ## Save

# %%
import pandas as pd

df = pd.DataFrame(data=embedding,index=smiles_list,columns=[f'latent_{i}' for i in range(embedding.shape[1])]) 

# Drop first feature from generator (RDKit2D_calculated)
df.drop(columns=['latent_0'], inplace=True)

# Drop columns with 0 standard deviation
threshold = 0.01
columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= threshold)[0]]
print(f'Deleting columns with std<={threshold}: {columns}')
df.drop(columns=[f'latent_{idx+1}' for idx in np.where(df.std() <= 0.01)[0]], inplace=True)
# Out:
# Deleting columns with std<=0.01: ['latent_90', 'latent_103', 'latent_152', 'latent_164', 'latent_187', 'latent_196']

# %% [markdown]
# Check that correct columns were deleted:

# %%
np.where(df.std() <= threshold)
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### Normalise dataframe

# %%
normalized_df=(df-df.mean())/df.std()

# %%
normalized_df.head()
# Out:
#                                             latent_1  latent_2  latent_3  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                1.828414 -1.981056 -1.401597
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                2.341124 -1.227141 -1.387455
# Brc1c(NC2=NCCN2)ccc2nccnc12                 0.363675 -0.866133 -1.145053
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2      -0.430884 -0.363848 -0.711002
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1 -0.771815 -0.489383 -0.680752
#
#                                             latent_4  latent_5  latent_6  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br               -1.634367 -0.356156 -1.597548
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br               -1.609569 -0.782456 -1.479081
# Brc1c(NC2=NCCN2)ccc2nccnc12                -1.177724 -1.027213 -1.082141
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2      -0.677713 -0.527146 -0.551143
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1 -0.698291 -0.431610 -0.554157
#
#                                             latent_7  latent_8  latent_9  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br               -1.621256 -0.436408 -1.475613
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br               -1.658517 -1.014979 -1.583002
# Brc1c(NC2=NCCN2)ccc2nccnc12                -1.148673 -1.071510 -1.198935
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2      -0.520575 -0.456924 -0.438653
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1 -0.623352 -0.352124 -0.649354
#
#                                             latent_10  ...  latent_190  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                 0.140887  ...   -0.233149
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                -0.829211  ...   -0.233149
# Brc1c(NC2=NCCN2)ccc2nccnc12                 -1.112825  ...   -0.233149
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2       -0.369559  ...   -0.233149
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1  -0.325339  ...   -0.233149
#
#                                             latent_191  latent_192  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                 -0.396236    -0.10286
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                 -0.396236    -0.10286
# Brc1c(NC2=NCCN2)ccc2nccnc12                  -0.396236    -0.10286
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2        -0.396236    -0.10286
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1   -0.396236    -0.10286
#
#                                             latent_193  latent_194  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                 -0.058325   -0.090007
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                 -0.058325   -0.090007
# Brc1c(NC2=NCCN2)ccc2nccnc12                  -0.058325   -0.090007
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2        -0.058325   -0.090007
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1   -0.058325   11.108842
#
#                                             latent_195  latent_197  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                 -0.172743   -0.206698
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                 -0.172743   -0.206698
# Brc1c(NC2=NCCN2)ccc2nccnc12                  -0.172743   -0.206698
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2        -0.172743   -0.206698
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1    5.464762   -0.206698
#
#                                             latent_198  latent_199  latent_200
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                 -0.187866   -0.351079   -0.815678
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                 -0.187866   -0.351079   -0.237036
# Brc1c(NC2=NCCN2)ccc2nccnc12                  -0.187866   -0.351079    1.394061
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2        -0.187866   -0.351079    0.795793
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1   -0.187866   -0.351079    0.911072
#
# [5 rows x 194 columns]

# %% [markdown]
# Check destination folder

# %%
EMBEDDING_DIR
# Out:
# PosixPath('/root/project/src/project_src/state_transition_model/benchmark/chemCPA/chemCPA-main/project_folder/embeddings')

# %%
model_name = 'rdkit2D'
dataset_name = 'lincs_trapnell'
fname = f'{model_name}_embedding_{dataset_name}.parquet'

directory = EMBEDDING_DIR /'rdkit' / 'data' /'embeddings'
directory.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Save normalised version

# %%
normalized_df.to_parquet(directory / fname)

# %% [markdown]
# Check that it worked

# %%
df = pd.read_parquet(directory/ fname)
df
# Out:
#                                                     latent_1  latent_2  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                        1.828414 -1.981056
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                        2.341124 -1.227141
# Brc1c(NC2=NCCN2)ccc2nccnc12                         0.363675 -0.866133
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2              -0.430884 -0.363848
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1         -0.771815 -0.489383
# ...                                                      ...       ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1   -0.701220 -0.052903
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c... -1.043611  0.711289
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1        -0.758711  0.225638
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1   -0.979916 -0.077524
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C... -1.404462  0.079986
#
#                                                     latent_3  latent_4  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                       -1.401597 -1.634367
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                       -1.387455 -1.609569
# Brc1c(NC2=NCCN2)ccc2nccnc12                        -1.145053 -1.177724
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2              -0.711002 -0.677713
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1         -0.680752 -0.698291
# ...                                                      ...       ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1   -0.482743 -0.419769
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c... -0.100867 -0.084774
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1        -0.482743 -0.486121
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1   -0.235467 -0.099588
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C... -0.265717 -0.175387
#
#                                                     latent_5  latent_6  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                       -0.356156 -1.597548
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                       -0.782456 -1.479081
# Brc1c(NC2=NCCN2)ccc2nccnc12                        -1.027213 -1.082141
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2              -0.527146 -0.551143
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1         -0.431610 -0.554157
# ...                                                      ...       ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1   -0.494723 -0.272670
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c... -0.159690  0.168823
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1        -0.561083 -0.272670
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1   -0.174506 -0.007172
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C... -0.250313 -0.010186
#
#                                                     latent_7  latent_8  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                       -1.621256 -0.436408
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                       -1.658517 -1.014979
# Brc1c(NC2=NCCN2)ccc2nccnc12                        -1.148673 -1.071510
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2              -0.520575 -0.456924
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1         -0.623352 -0.352124
# ...                                                      ...       ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1   -0.294573 -0.420919
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...  0.000405 -0.132287
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1        -0.438979 -0.562218
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1    0.100338 -0.034503
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C... -0.011393 -0.143831
#
#                                                     latent_9  latent_10  ...  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                       -1.475613   0.140887  ...
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                       -1.583002  -0.829211  ...
# Brc1c(NC2=NCCN2)ccc2nccnc12                        -1.198935  -1.112825  ...
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2              -0.438653  -0.369559  ...
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1         -0.649354  -0.325339  ...
# ...                                                      ...        ...  ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1   -0.367549  -0.535261  ...
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c... -0.134112  -0.312200  ...
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1        -0.519458  -0.680419  ...
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1   -0.021827  -0.204905  ...
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...  0.061217  -0.125553  ...
#
#                                                     latent_190  latent_191  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                         -0.233149   -0.396236
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                         -0.233149   -0.396236
# Brc1c(NC2=NCCN2)ccc2nccnc12                          -0.233149   -0.396236
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2                -0.233149   -0.396236
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1           -0.233149   -0.396236
# ...                                                        ...         ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1     -0.233149   -0.396236
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...   -0.233149   -0.396236
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1          -0.233149   -0.396236
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1     -0.233149   -0.396236
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...   -0.233149   -0.396236
#
#                                                     latent_192  latent_193  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                          -0.10286   -0.058325
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                          -0.10286   -0.058325
# Brc1c(NC2=NCCN2)ccc2nccnc12                           -0.10286   -0.058325
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2                 -0.10286   -0.058325
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1            -0.10286   -0.058325
# ...                                                        ...         ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1      -0.10286   -0.058325
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...    -0.10286   -0.058325
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1           -0.10286   -0.058325
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1      -0.10286   -0.058325
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...    -0.10286   -0.058325
#
#                                                     latent_194  latent_195  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                         -0.090007   -0.172743
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                         -0.090007   -0.172743
# Brc1c(NC2=NCCN2)ccc2nccnc12                          -0.090007   -0.172743
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2                -0.090007   -0.172743
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1           11.108842    5.464762
# ...                                                        ...         ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1     -0.090007   -0.172743
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...   -0.090007   -0.172743
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1          -0.090007   -0.172743
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1     -0.090007   -0.172743
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...   -0.090007   -0.172743
#
#                                                     latent_197  latent_198  \
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                         -0.206698   -0.187866
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                         -0.206698   -0.187866
# Brc1c(NC2=NCCN2)ccc2nccnc12                          -0.206698   -0.187866
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2                -0.206698   -0.187866
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1           -0.206698   -0.187866
# ...                                                        ...         ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1     -0.206698   -0.187866
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...   -0.206698   -0.187866
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1          -0.206698   -0.187866
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1     -0.206698   -0.187866
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...   -0.206698   -0.187866
#
#                                                     latent_199  latent_200
# BrC1C(Br)C(Br)C(Br)C(Br)C1Br                         -0.351079   -0.815678
# Brc1c(Br)c(Br)c2[nH]nnc2c1Br                         -0.351079   -0.237036
# Brc1c(NC2=NCCN2)ccc2nccnc12                          -0.351079    1.394061
# Brc1cc2c(cc1C1Nc3ccccc3C3C=CCC31)OCO2                -0.351079    0.795793
# Brc1ccc(-c2csc(N3CCC(c4nn[nH]n4)CC3)n2)cc1           -0.351079    0.911072
# ...                                                        ...         ...
# c1nc(NC[C@@H]2CCCO2)c2cc(-c3ccc4c(c3)OCO4)ccc2n1     -0.351079    1.082694
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)c...   -0.351079   -0.099951
# c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2n1          -0.351079    0.216967
# c1nc2c(NC3CCCCC3)nc(Nc3ccc(N4CCOCC4)cc3)nc2[nH]1     -0.351079    0.275954
# c1ncc(-c2ccc([C@H]3[C@@H]4CN(Cc5ccc6c(c5)OCO6)C...   -0.351079    0.928697
#
# [7963 rows x 194 columns]
